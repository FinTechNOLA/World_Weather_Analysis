# %%
# Import Dependencies
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,  high=90.000, size=2000)
lngs = np.random.uniform(low=-90.00, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine the city based on the latitude and the longitude
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, we'll add to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %%
# Import the requests library.
import requests

# Import the API key
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module fromt the datetime library.
from datetime import datetime
import time

# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging.
print ("Beginning Data Retrieval      ")
print("-------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through the cities in our list.
for i, city in enumerate(cities):
    
    # Group the cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create an endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API Request for each of the cities
    try:
        # Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to the ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Date": city_date})
        
 # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indication that the Data Loading is complete.
print("-----------------------------------")
print("Data Retrieval Complete            ")
print("-----------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | itaituba
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | gualeguay
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | valday
# Processing Record 10 of Set 1 | colares
# Processing Record 11 of Set 1 | hauterive
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | strezhevoy
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | atasu
# Processing Record 18 of Set 1 | phuntsholing
# Processing Record 19 of Set 1 | ponta delgada
# Processing Record 20 of Set 1 | formosa
# Processing Record 21 of Set 1 | kamenka
# Processing Record 22 of Set 1 | codrington
# Processing Record 23 of Set 1 | sisimiut
# Processing Record 24 of Set 1 | partyzany
# Processing Record 25 of Set 1 | sao jose de ribamar
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | puerto maldonado
# Processing Record 31 of Set 1 | taltal
# Processing Record 32 of Set 1 | luderitz
# Processing Record 33 of Set 1 | ariquemes
# Processing Record 34 of Set 1 | kachiry
# Processing Record 35 of Set 1 | antalaha
# Processing Record 36 of Set 1 | grand baie
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | cayenne
# Processing Record 39 of Set 1 | saldanha
# Processing Record 40 of Set 1 | wlodawa
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | maxixe
# Processing Record 43 of Set 1 | clarksburg
# Processing Record 44 of Set 1 | laguna
# Processing Record 45 of Set 1 | marfino
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | ostrovnoy
# Processing Record 48 of Set 1 | haverfordwest
# Processing Record 49 of Set 1 | orapa
# Processing Record 50 of Set 1 | harindanga
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | high rock
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | behbahan
# Processing Record 6 of Set 2 | luau
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | santa maria
# Processing Record 9 of Set 2 | umba
# Processing Record 10 of Set 2 | berlevag
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | los llanos de aridane
# Processing Record 13 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 2 | mwense
# Processing Record 15 of Set 2 | karwar
# Processing Record 16 of Set 2 | la asuncion
# Processing Record 17 of Set 2 | poole
# Processing Record 18 of Set 2 | benguela
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | sao borja
# Processing Record 21 of Set 2 | robertsport
# Processing Record 22 of Set 2 | dortyol
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | darnah
# Processing Record 27 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 2 | varzea da palma
# Processing Record 30 of Set 2 | paamiut
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | chamalieres
# Processing Record 34 of Set 2 | saint-joseph
# Processing Record 35 of Set 2 | hurghada
# Processing Record 36 of Set 2 | lady lake
# Processing Record 37 of Set 2 | nouadhibou
# Processing Record 38 of Set 2 | ormara
# Processing Record 39 of Set 2 | vardo
# Processing Record 40 of Set 2 | astana
# Processing Record 41 of Set 2 | mirabad
# Processing Record 42 of Set 2 | staryy nadym
# Processing Record 43 of Set 2 | pitimbu
# Processing Record 44 of Set 2 | brahmapuri
# City not found. Skipping...
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | adrar
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | novyy urengoy
# Processing Record 49 of Set 2 | dakoro
# Processing Record 50 of Set 2 | faya
# Processing Record 1 of Set 3 | caravelas
# Processing Record 2 of Set 3 | hattiesburg
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 3 | camana
# Processing Record 6 of Set 3 | manthani
# Processing Record 7 of Set 3 | dingle
# Processing Record 8 of Set 3 | sabratah
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | ovalle
# Processing Record 11 of Set 3 | riyadh
# Processing Record 12 of Set 3 | corrales
# Processing Record 13 of Set 3 | kurchum
# Processing Record 14 of Set 3 | santana do livramento
# Processing Record 15 of Set 3 | kotturu
# Processing Record 16 of Set 3 | bar-le-duc
# Processing Record 17 of Set 3 | hatillo
# Processing Record 18 of Set 3 | nouakchott
# Processing Record 19 of Set 3 | kathmandu
# Processing Record 20 of Set 3 | serenje
# Processing Record 21 of Set 3 | sakaraha
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | belyy yar
# Processing Record 24 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 3 | kangaatsiaq
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | oistins
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | sovetskiy
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | ndago
# Processing Record 32 of Set 3 | muli
# Processing Record 33 of Set 3 | chulym
# Processing Record 34 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 35 of Set 3 | bohuslav
# Processing Record 36 of Set 3 | ugoofaaru
# Processing Record 37 of Set 3 | atar
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | punta arenas
# Processing Record 40 of Set 3 | korla
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 3 | ilorin
# Processing Record 44 of Set 3 | nuuk
# Processing Record 45 of Set 3 | raga
# Processing Record 46 of Set 3 | aparecida do taboado
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | aswan
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | kalininsk
# Processing Record 1 of Set 4 | eyl
# Processing Record 2 of Set 4 | porto velho
# Processing Record 3 of Set 4 | barmer
# Processing Record 4 of Set 4 | kodinar
# Processing Record 5 of Set 4 | lloret de mar
# Processing Record 6 of Set 4 | pangnirtung
# Processing Record 7 of Set 4 | sonqor
# Processing Record 8 of Set 4 | veraval
# Processing Record 9 of Set 4 | grieskirchen
# Processing Record 10 of Set 4 | torbay
# Processing Record 11 of Set 4 | springfield
# Processing Record 12 of Set 4 | taoudenni
# Processing Record 13 of Set 4 | marovoay
# Processing Record 14 of Set 4 | warrington
# Processing Record 15 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 4 | nova olimpia
# Processing Record 17 of Set 4 | marienburg
# Processing Record 18 of Set 4 | tukrah
# Processing Record 19 of Set 4 | sambava
# Processing Record 20 of Set 4 | ullubiyaul
# Processing Record 21 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | comodoro rivadavia
# Processing Record 26 of Set 4 | nau
# Processing Record 27 of Set 4 | kaliganj
# Processing Record 28 of Set 4 | goderich
# Processing Record 29 of Set 4 | aksu
# Processing Record 30 of Set 4 | port-gentil
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | rawson
# Processing Record 33 of Set 4 | islamkot
# Processing Record 34 of Set 4 | ankazoabo
# Processing Record 35 of Set 4 | aku
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | princeville
# Processing Record 38 of Set 4 | harper
# Processing Record 39 of Set 4 | brae
# Processing Record 40 of Set 4 | inhambane
# Processing Record 41 of Set 4 | nacala
# Processing Record 42 of Set 4 | kuvandyk
# Processing Record 43 of Set 4 | havoysund
# Processing Record 44 of Set 4 | kulhudhuffushi
# Processing Record 45 of Set 4 | pachino
# Processing Record 46 of Set 4 | richards bay
# Processing Record 47 of Set 4 | gavle
# Processing Record 48 of Set 4 | mbarara
# Processing Record 49 of Set 4 | camacha
# Processing Record 50 of Set 4 | sorland
# Processing Record 1 of Set 5 | liverpool
# Processing Record 2 of Set 5 | varkaus
# Processing Record 3 of Set 5 | carutapera
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | gilgit
# Processing Record 6 of Set 5 | tazovskiy
# Processing Record 7 of Set 5 | khorixas
# Processing Record 8 of Set 5 | bluefield
# Processing Record 9 of Set 5 | opuwo
# Processing Record 10 of Set 5 | la esperanza
# Processing Record 11 of Set 5 | pombas
# Processing Record 12 of Set 5 | epernay
# Processing Record 13 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 14 of Set 5 | iracoubo
# Processing Record 15 of Set 5 | kalomo
# City not found. Skipping...
# Processing Record 16 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 5 | ahero
# Processing Record 18 of Set 5 | akureyri
# Processing Record 19 of Set 5 | hobyo
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | cockburn town
# Processing Record 22 of Set 5 | soyo
# Processing Record 23 of Set 5 | umm lajj
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | gat
# Processing Record 26 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 27 of Set 5 | san cristobal
# Processing Record 28 of Set 5 | ponta do sol
# Processing Record 29 of Set 5 | zapolyarnyy
# Processing Record 30 of Set 5 | sept-iles
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | puerto leguizamo
# Processing Record 33 of Set 5 | chilakalurupet
# Processing Record 34 of Set 5 | nizhnyaya tavda
# Processing Record 35 of Set 5 | zatoka
# Processing Record 36 of Set 5 | synya
# Processing Record 37 of Set 5 | belmonte
# Processing Record 38 of Set 5 | ruwi
# Processing Record 39 of Set 5 | kita
# Processing Record 40 of Set 5 | sao joao da barra
# Processing Record 41 of Set 5 | americus
# Processing Record 42 of Set 5 | dedza
# Processing Record 43 of Set 5 | amos
# Processing Record 44 of Set 5 | salalah
# Processing Record 45 of Set 5 | gaeta
# Processing Record 46 of Set 5 | hambantota
# Processing Record 47 of Set 5 | kemijarvi
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | kayerkan
# Processing Record 50 of Set 5 | le vauclin
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | raahe
# Processing Record 3 of Set 6 | gornopravdinsk
# Processing Record 4 of Set 6 | kankon
# Processing Record 5 of Set 6 | camabatela
# Processing Record 6 of Set 6 | marathon
# Processing Record 7 of Set 6 | wajir
# Processing Record 8 of Set 6 | beira
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | jabinyanah
# Processing Record 12 of Set 6 | orocue
# Processing Record 13 of Set 6 | coquimbo
# Processing Record 14 of Set 6 | omboue
# Processing Record 15 of Set 6 | joao pinheiro
# Processing Record 16 of Set 6 | dunmore east
# Processing Record 17 of Set 6 | tsiroanomandidy
# Processing Record 18 of Set 6 | abu samrah
# Processing Record 19 of Set 6 | olot
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | itarema
# Processing Record 22 of Set 6 | mehamn
# Processing Record 23 of Set 6 | mlowo
# Processing Record 24 of Set 6 | buraydah
# Processing Record 25 of Set 6 | venice
# Processing Record 26 of Set 6 | necochea
# Processing Record 27 of Set 6 | quatre cocos
# Processing Record 28 of Set 6 | dudinka
# Processing Record 29 of Set 6 | zhezkazgan
# Processing Record 30 of Set 6 | shelburne
# Processing Record 31 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 6 | moron
# Processing Record 33 of Set 6 | benidorm
# Processing Record 34 of Set 6 | san miguel
# Processing Record 35 of Set 6 | skibbereen
# Processing Record 36 of Set 6 | tambovka
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | obukhiv
# Processing Record 39 of Set 6 | mulchen
# Processing Record 40 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 6 | songea
# Processing Record 42 of Set 6 | semnan
# Processing Record 43 of Set 6 | derzhavinsk
# Processing Record 44 of Set 6 | rio cuarto
# Processing Record 45 of Set 6 | viedma
# Processing Record 46 of Set 6 | yacuiba
# Processing Record 47 of Set 6 | liwale
# Processing Record 48 of Set 6 | coihueco
# Processing Record 49 of Set 6 | ziyamet
# City not found. Skipping...
# Processing Record 50 of Set 6 | buka
# Processing Record 1 of Set 7 | stamsund
# City not found. Skipping...
# Processing Record 2 of Set 7 | belomorsk
# Processing Record 3 of Set 7 | praia
# Processing Record 4 of Set 7 | obo
# Processing Record 5 of Set 7 | shakiso
# Processing Record 6 of Set 7 | skjervoy
# Processing Record 7 of Set 7 | puerto madryn
# Processing Record 8 of Set 7 | usinsk
# Processing Record 9 of Set 7 | mao
# Processing Record 10 of Set 7 | matagami
# Processing Record 11 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 7 | tanout
# Processing Record 13 of Set 7 | vagur
# Processing Record 14 of Set 7 | vyartsilya
# Processing Record 15 of Set 7 | yar-sale
# Processing Record 16 of Set 7 | sinnamary
# Processing Record 17 of Set 7 | chhatarpur
# Processing Record 18 of Set 7 | shinpokh
# Processing Record 19 of Set 7 | verkhoturye
# Processing Record 20 of Set 7 | campana
# Processing Record 21 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 7 | virginia beach
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | aljezur
# Processing Record 25 of Set 7 | rio gallegos
# Processing Record 26 of Set 7 | sechura
# Processing Record 27 of Set 7 | misratah
# Processing Record 28 of Set 7 | kisleta
# Processing Record 29 of Set 7 | le port
# Processing Record 30 of Set 7 | pascagoula
# Processing Record 31 of Set 7 | dwarka
# Processing Record 32 of Set 7 | staritsa
# Processing Record 33 of Set 7 | bengkulu
# Processing Record 34 of Set 7 | grand gaube
# Processing Record 35 of Set 7 | kilrush
# Processing Record 36 of Set 7 | breytovo
# Processing Record 37 of Set 7 | karacakoy
# Processing Record 38 of Set 7 | puno
# Processing Record 39 of Set 7 | mundwa
# Processing Record 40 of Set 7 | ilo
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | lokosovo
# Processing Record 44 of Set 7 | sao filipe
# Processing Record 45 of Set 7 | castro
# Processing Record 46 of Set 7 | yevlax
# Processing Record 47 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 48 of Set 7 | kazerun
# Processing Record 49 of Set 7 | muscle shoals
# Processing Record 50 of Set 7 | morondava
# Processing Record 1 of Set 8 | harfleur
# Processing Record 2 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 3 of Set 8 | naifaru
# Processing Record 4 of Set 8 | sao joao batista
# Processing Record 5 of Set 8 | arona
# Processing Record 6 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | newark
# Processing Record 9 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 8 | imst
# Processing Record 11 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 8 | santa fe
# Processing Record 13 of Set 8 | mgandu
# Processing Record 14 of Set 8 | general pico
# Processing Record 15 of Set 8 | rocha
# Processing Record 16 of Set 8 | mlyniv
# Processing Record 17 of Set 8 | kiyasovo
# Processing Record 18 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 8 | carbonia
# Processing Record 20 of Set 8 | hammerfest
# Processing Record 21 of Set 8 | margate
# Processing Record 22 of Set 8 | olafsvik
# Processing Record 23 of Set 8 | carikar
# City not found. Skipping...
# Processing Record 24 of Set 8 | andros town
# Processing Record 25 of Set 8 | huicungo
# Processing Record 26 of Set 8 | santa cruz de la palma
# Processing Record 27 of Set 8 | jacareacanga
# Processing Record 28 of Set 8 | leshukonskoye
# Processing Record 29 of Set 8 | bar harbor
# Processing Record 30 of Set 8 | lena
# Processing Record 31 of Set 8 | mamallapuram
# Processing Record 32 of Set 8 | wobulenzi
# Processing Record 33 of Set 8 | lere
# Processing Record 34 of Set 8 | gbarnga
# Processing Record 35 of Set 8 | neuquen
# Processing Record 36 of Set 8 | port blair
# Processing Record 37 of Set 8 | aguilar de la frontera
# Processing Record 38 of Set 8 | vuktyl
# Processing Record 39 of Set 8 | cape canaveral
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | talcahuano
# Processing Record 42 of Set 8 | nador
# Processing Record 43 of Set 8 | saint-georges
# Processing Record 44 of Set 8 | andenes
# Processing Record 45 of Set 8 | kuytun
# Processing Record 46 of Set 8 | am timan
# Processing Record 47 of Set 8 | ilheus
# Processing Record 48 of Set 8 | tabuk
# Processing Record 49 of Set 8 | burica
# City not found. Skipping...
# Processing Record 50 of Set 8 | cap-aux-meules
# Processing Record 1 of Set 9 | barcelos
# Processing Record 2 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 9 | peniche
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | millinocket
# Processing Record 6 of Set 9 | lakselv
# Processing Record 7 of Set 9 | yurimaguas
# Processing Record 8 of Set 9 | kondinskoye
# Processing Record 9 of Set 9 | vila franca do campo
# Processing Record 10 of Set 9 | narovchat
# Processing Record 11 of Set 9 | luanda
# Processing Record 12 of Set 9 | gwadar
# Processing Record 13 of Set 9 | masuri
# Processing Record 14 of Set 9 | sudova vyshnya
# Processing Record 15 of Set 9 | general roca
# Processing Record 16 of Set 9 | santa cruz
# Processing Record 17 of Set 9 | nassau
# Processing Record 18 of Set 9 | doka
# Processing Record 19 of Set 9 | balkanabat
# Processing Record 20 of Set 9 | matay
# Processing Record 21 of Set 9 | kalmunai
# Processing Record 22 of Set 9 | cap malheureux
# Processing Record 23 of Set 9 | masalli
# Processing Record 24 of Set 9 | piacabucu
# Processing Record 25 of Set 9 | aripuana
# Processing Record 26 of Set 9 | cubuk
# Processing Record 27 of Set 9 | svetlyy
# Processing Record 28 of Set 9 | bauska
# Processing Record 29 of Set 9 | saint anthony
# Processing Record 30 of Set 9 | mahibadhoo
# Processing Record 31 of Set 9 | taperoa
# Processing Record 32 of Set 9 | cordoba
# Processing Record 33 of Set 9 | taywarah
# Processing Record 34 of Set 9 | lexington park
# Processing Record 35 of Set 9 | landerneau
# Processing Record 36 of Set 9 | arrecife
# Processing Record 37 of Set 9 | sturgeon falls
# Processing Record 38 of Set 9 | ilinskiy
# Processing Record 39 of Set 9 | leh
# Processing Record 40 of Set 9 | manjeri
# Processing Record 41 of Set 9 | karpogory
# Processing Record 42 of Set 9 | trud
# Processing Record 43 of Set 9 | dinar
# Processing Record 44 of Set 9 | skorodnoye
# Processing Record 45 of Set 9 | dabat
# Processing Record 46 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 47 of Set 9 | zaria
# Processing Record 48 of Set 9 | pitkyaranta
# Processing Record 49 of Set 9 | aquiraz
# Processing Record 50 of Set 9 | saint-ambroise
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | ascona
# Processing Record 3 of Set 10 | tiznit
# Processing Record 4 of Set 10 | keffi
# Processing Record 5 of Set 10 | asyut
# Processing Record 6 of Set 10 | tacuati
# Processing Record 7 of Set 10 | huntingdon
# Processing Record 8 of Set 10 | of
# City not found. Skipping...
# Processing Record 9 of Set 10 | sabha
# Processing Record 10 of Set 10 | iqaluit
# Processing Record 11 of Set 10 | nantucket
# Processing Record 12 of Set 10 | san pedro
# Processing Record 13 of Set 10 | asosa
# Processing Record 14 of Set 10 | nurota
# Processing Record 15 of Set 10 | englehart
# Processing Record 16 of Set 10 | urubamba
# Processing Record 17 of Set 10 | matara
# Processing Record 18 of Set 10 | thompson
# Processing Record 19 of Set 10 | mantua
# Processing Record 20 of Set 10 | tara
# Processing Record 21 of Set 10 | hornepayne
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | pasinler
# Processing Record 24 of Set 10 | sumbe
# Processing Record 25 of Set 10 | port-cartier
# Processing Record 26 of Set 10 | yartsevo
# Processing Record 27 of Set 10 | ampanihy
# Processing Record 28 of Set 10 | alipur
# Processing Record 29 of Set 10 | sokolo
# Processing Record 30 of Set 10 | medvedovskaya
# Processing Record 31 of Set 10 | vestmannaeyjar
# Processing Record 32 of Set 10 | unai
# Processing Record 33 of Set 10 | kumluca
# Processing Record 34 of Set 10 | bermeo
# Processing Record 35 of Set 10 | manaus
# Processing Record 36 of Set 10 | bonfim
# Processing Record 37 of Set 10 | ilam
# Processing Record 38 of Set 10 | kutum
# Processing Record 39 of Set 10 | sur
# Processing Record 40 of Set 10 | tanhacu
# Processing Record 41 of Set 10 | janow lubelski
# Processing Record 42 of Set 10 | cururupu
# Processing Record 43 of Set 10 | yamoussoukro
# Processing Record 44 of Set 10 | dunmore town
# Processing Record 45 of Set 10 | reitz
# Processing Record 46 of Set 10 | sarankhola
# Processing Record 47 of Set 10 | la palma
# Processing Record 48 of Set 10 | san rafael del sur
# Processing Record 49 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 10 | puri
# Processing Record 1 of Set 11 | presidencia roque saenz pena
# Processing Record 2 of Set 11 | miquelon
# Processing Record 3 of Set 11 | geraldton
# Processing Record 4 of Set 11 | porbandar
# Processing Record 5 of Set 11 | maniitsoq
# Processing Record 6 of Set 11 | otacilio costa
# Processing Record 7 of Set 11 | qunduz
# Processing Record 8 of Set 11 | palmas
# Processing Record 9 of Set 11 | harlingen
# Processing Record 10 of Set 11 | mendi
# Processing Record 11 of Set 11 | olinda
# Processing Record 12 of Set 11 | kaduqli
# Processing Record 13 of Set 11 | mweka
# Processing Record 14 of Set 11 | banda aceh
# Processing Record 15 of Set 11 | rab
# City not found. Skipping...
# Processing Record 16 of Set 11 | paragominas
# Processing Record 17 of Set 11 | gamba
# Processing Record 18 of Set 11 | kismayo
# Processing Record 19 of Set 11 | jalu
# Processing Record 20 of Set 11 | segou
# Processing Record 21 of Set 11 | diffa
# Processing Record 22 of Set 11 | melo
# Processing Record 23 of Set 11 | jutai
# Processing Record 24 of Set 11 | talalayivka
# Processing Record 25 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 26 of Set 11 | marzuq
# Processing Record 27 of Set 11 | mancora
# Processing Record 28 of Set 11 | oil city
# Processing Record 29 of Set 11 | gazanjyk
# Processing Record 30 of Set 11 | polyanka
# Processing Record 31 of Set 11 | santa flavia
# Processing Record 32 of Set 11 | ierapetra
# Processing Record 33 of Set 11 | bure
# Processing Record 34 of Set 11 | caconda
# Processing Record 35 of Set 11 | rio grande
# Processing Record 36 of Set 11 | padang
# Processing Record 37 of Set 11 | tunceli
# Processing Record 38 of Set 11 | ust-kulom
# Processing Record 39 of Set 11 | san carlos
# Processing Record 40 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 41 of Set 11 | amapa
# Processing Record 42 of Set 11 | vallenar
# Processing Record 43 of Set 11 | mezen
# Processing Record 44 of Set 11 | saint-augustin
# Processing Record 45 of Set 11 | westport
# Processing Record 46 of Set 11 | cartagena
# Processing Record 47 of Set 11 | pandharpur
# Processing Record 48 of Set 11 | shahrud
# Processing Record 49 of Set 11 | marrakesh
# Processing Record 50 of Set 11 | rosetta
# Processing Record 1 of Set 12 | san felipe
# Processing Record 2 of Set 12 | marsh harbour
# Processing Record 3 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 12 | sabzevar
# Processing Record 5 of Set 12 | cuamba
# Processing Record 6 of Set 12 | kopervik
# Processing Record 7 of Set 12 | port hawkesbury
# Processing Record 8 of Set 12 | porto novo
# Processing Record 9 of Set 12 | progreso
# Processing Record 10 of Set 12 | la solana
# Processing Record 11 of Set 12 | kalmar
# Processing Record 12 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 13 of Set 12 | atlantic city
# Processing Record 14 of Set 12 | cadiz
# Processing Record 15 of Set 12 | mount darwin
# Processing Record 16 of Set 12 | praia da vitoria
# Processing Record 17 of Set 12 | rayagada
# Processing Record 18 of Set 12 | husavik
# Processing Record 19 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 12 | albany
# Processing Record 21 of Set 12 | boma
# Processing Record 22 of Set 12 | trairi
# Processing Record 23 of Set 12 | kuusamo
# Processing Record 24 of Set 12 | mankono
# Processing Record 25 of Set 12 | bombay
# Processing Record 26 of Set 12 | ambasamudram
# Processing Record 27 of Set 12 | djibo
# Processing Record 28 of Set 12 | buchanan
# Processing Record 29 of Set 12 | bella vista
# Processing Record 30 of Set 12 | licata
# Processing Record 31 of Set 12 | marsa matruh
# Processing Record 32 of Set 12 | kaffrine
# Processing Record 33 of Set 12 | chapadinha
# Processing Record 34 of Set 12 | grand-santi
# Processing Record 35 of Set 12 | doha
# Processing Record 36 of Set 12 | shubarshi
# Processing Record 37 of Set 12 | dhidhdhoo
# Processing Record 38 of Set 12 | novoukrainskiy
# Processing Record 39 of Set 12 | savannah bight
# Processing Record 40 of Set 12 | saint-leu
# Processing Record 41 of Set 12 | molteno
# Processing Record 42 of Set 12 | abrau-dyurso
# Processing Record 43 of Set 12 | axim
# Processing Record 44 of Set 12 | bansang
# Processing Record 45 of Set 12 | shirhatti
# Processing Record 46 of Set 12 | terra roxa
# Processing Record 47 of Set 12 | ihtiman
# Processing Record 48 of Set 12 | azrow
# City not found. Skipping...
# Processing Record 49 of Set 12 | key west
# Processing Record 50 of Set 12 | khash
# Processing Record 1 of Set 13 | the valley
# Processing Record 2 of Set 13 | laon
# Processing Record 3 of Set 13 | tapes
# Processing Record 4 of Set 13 | matam
# Processing Record 5 of Set 13 | mogadishu
# Processing Record 6 of Set 13 | oriximina
# Processing Record 7 of Set 13 | puerto ayora
# Processing Record 8 of Set 13 | lubango
# Processing Record 9 of Set 13 | sao felix do xingu
# Processing Record 10 of Set 13 | kindu
# Processing Record 11 of Set 13 | uvat
# Processing Record 12 of Set 13 | youghal
# Processing Record 13 of Set 13 | ambilobe
# Processing Record 14 of Set 13 | ibra
# Processing Record 15 of Set 13 | urumqi
# Processing Record 16 of Set 13 | walvis bay
# Processing Record 17 of Set 13 | chesma
# Processing Record 18 of Set 13 | cajnice
# Processing Record 19 of Set 13 | wamba
# Processing Record 20 of Set 13 | ajdabiya
# Processing Record 21 of Set 13 | nsanje
# Processing Record 22 of Set 13 | oranjemund
# Processing Record 23 of Set 13 | mosquera
# Processing Record 24 of Set 13 | outjo
# Processing Record 25 of Set 13 | qaqortoq
# Processing Record 26 of Set 13 | manta
# Processing Record 27 of Set 13 | huarmey
# Processing Record 28 of Set 13 | el alto
# Processing Record 29 of Set 13 | andra
# Processing Record 30 of Set 13 | esmeralda
# Processing Record 31 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 13 | linhares
# Processing Record 34 of Set 13 | guarapari
# Processing Record 35 of Set 13 | tirumala
# Processing Record 36 of Set 13 | pueblo bello
# Processing Record 37 of Set 13 | birin
# Processing Record 38 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 13 | durango
# Processing Record 40 of Set 13 | accra
# Processing Record 41 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 13 | ottawa
# Processing Record 43 of Set 13 | toktogul
# Processing Record 44 of Set 13 | jardim
# Processing Record 45 of Set 13 | rubtsovsk
# Processing Record 46 of Set 13 | havre-saint-pierre
# Processing Record 47 of Set 13 | chateauroux
# Processing Record 48 of Set 13 | vilhena
# Processing Record 49 of Set 13 | chiredzi
# Processing Record 50 of Set 13 | mattru
# Processing Record 1 of Set 14 | old saybrook
# Processing Record 2 of Set 14 | tres lagoas
# Processing Record 3 of Set 14 | ouadda
# Processing Record 4 of Set 14 | annau
# Processing Record 5 of Set 14 | tatawin
# Processing Record 6 of Set 14 | gudiyattam
# City not found. Skipping...
# Processing Record 7 of Set 14 | manavalakurichi
# Processing Record 8 of Set 14 | abeche
# Processing Record 9 of Set 14 | plymouth
# Processing Record 10 of Set 14 | yaviza
# Processing Record 11 of Set 14 | san francisco
# Processing Record 12 of Set 14 | noyabrsk
# Processing Record 13 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 14 | calama
# Processing Record 15 of Set 14 | parabel
# Processing Record 16 of Set 14 | pompeu
# Processing Record 17 of Set 14 | graaff-reinet
# Processing Record 18 of Set 14 | abha
# Processing Record 19 of Set 14 | nzerekore
# Processing Record 20 of Set 14 | balkhash
# Processing Record 21 of Set 14 | mitsamiouli
# Processing Record 22 of Set 14 | boly
# Processing Record 23 of Set 14 | huambo
# Processing Record 24 of Set 14 | placido de castro
# Processing Record 25 of Set 14 | kribi
# Processing Record 26 of Set 14 | morant bay
# Processing Record 27 of Set 14 | jetalsar
# Processing Record 28 of Set 14 | jubb jannin
# City not found. Skipping...
# Processing Record 29 of Set 14 | pacatuba
# Processing Record 30 of Set 14 | biharamulo
# Processing Record 31 of Set 14 | grevena
# Processing Record 32 of Set 14 | shakawe
# Processing Record 33 of Set 14 | saint-gaudens
# Processing Record 34 of Set 14 | mana
# Processing Record 35 of Set 14 | thinadhoo
# Processing Record 36 of Set 14 | dahuk
# Processing Record 37 of Set 14 | kuminskiy
# Processing Record 38 of Set 14 | luba
# Processing Record 39 of Set 14 | isiolo
# Processing Record 40 of Set 14 | ipameri
# Processing Record 41 of Set 14 | ikom
# Processing Record 42 of Set 14 | ryazanovskiy
# Processing Record 43 of Set 14 | bronkhorstspruit
# Processing Record 44 of Set 14 | gimbi
# Processing Record 45 of Set 14 | maun
# Processing Record 46 of Set 14 | nizwa
# Processing Record 47 of Set 14 | tessalit
# Processing Record 48 of Set 14 | tarrafal
# Processing Record 49 of Set 14 | lethem
# Processing Record 50 of Set 14 | weligama
# Processing Record 1 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 15 | la peca
# Processing Record 3 of Set 15 | kopavogur
# Processing Record 4 of Set 15 | hyeres
# Processing Record 5 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 6 of Set 15 | vinderup
# Processing Record 7 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 15 | ifanadiana
# Processing Record 9 of Set 15 | bandarbeyla
# Processing Record 10 of Set 15 | sinop
# Processing Record 11 of Set 15 | bugarama
# Processing Record 12 of Set 15 | sucre
# Processing Record 13 of Set 15 | lipari
# Processing Record 14 of Set 15 | usogorsk
# Processing Record 15 of Set 15 | burgeo
# Processing Record 16 of Set 15 | westerland
# Processing Record 17 of Set 15 | augusta
# Processing Record 18 of Set 15 | mitu
# Processing Record 19 of Set 15 | emba
# Processing Record 20 of Set 15 | ndjole
# Processing Record 21 of Set 15 | machado
# Processing Record 22 of Set 15 | pickerington
# Processing Record 23 of Set 15 | modasa
# Processing Record 24 of Set 15 | puerto del rosario
# Processing Record 25 of Set 15 | amot
# Processing Record 26 of Set 15 | maniwaki
# Processing Record 27 of Set 15 | ivanava
# Processing Record 28 of Set 15 | yarada
# Processing Record 29 of Set 15 | trincomalee
# Processing Record 30 of Set 15 | keti bandar
# Processing Record 31 of Set 15 | pudozh
# Processing Record 32 of Set 15 | sharjah
# Processing Record 33 of Set 15 | farah
# Processing Record 34 of Set 15 | gjirokaster
# Processing Record 35 of Set 15 | alanya
# Processing Record 36 of Set 15 | zhanaozen
# Processing Record 37 of Set 15 | orgun
# City not found. Skipping...
# Processing Record 38 of Set 15 | krasnoselkup
# Processing Record 39 of Set 15 | dasoguz
# Processing Record 40 of Set 15 | jimani
# Processing Record 41 of Set 15 | pedernales
# Processing Record 42 of Set 15 | karaton
# Processing Record 43 of Set 15 | stornoway
# Processing Record 44 of Set 15 | sinazongwe
# Processing Record 45 of Set 15 | soltsy
# Processing Record 46 of Set 15 | kpandu
# Processing Record 47 of Set 15 | diego de almagro
# Processing Record 48 of Set 15 | loiza
# Processing Record 49 of Set 15 | borba
# Processing Record 50 of Set 15 | beboto
# Processing Record 1 of Set 16 | lebanon
# Processing Record 2 of Set 16 | knysna
# Processing Record 3 of Set 16 | valavanur
# Processing Record 4 of Set 16 | xai-xai
# Processing Record 5 of Set 16 | siniscola
# Processing Record 6 of Set 16 | san carlos de bariloche
# Processing Record 7 of Set 16 | ostersund
# Processing Record 8 of Set 16 | solwezi
# Processing Record 9 of Set 16 | gobabis
# Processing Record 10 of Set 16 | mecca
# Processing Record 11 of Set 16 | qadian
# Processing Record 12 of Set 16 | miasskoye
# Processing Record 13 of Set 16 | menongue
# Processing Record 14 of Set 16 | bhatkal
# Processing Record 15 of Set 16 | zonguldak
# Processing Record 16 of Set 16 | parrita
# Processing Record 17 of Set 16 | chrzanow
# Processing Record 18 of Set 16 | kibuye
# -----------------------------------
# Data Retrieval Complete
# -----------------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Itaituba      BR  -4.2761 -55.9836     70.50        96          55
# 1  Upernavik      GL  72.7868 -56.1549      9.27        92         100
# 2  Cape Town      ZA -33.9258  18.4232     77.11        43          28
# 3    Ushuaia      AR -54.8000 -68.3000     32.92        88          16
# 4  Gualeguay      AR -33.1416 -59.3097     66.06        88           0
#
#    Wind Speed                 Date
# 0        1.97  2022-02-04 09:07:04
# 1        9.40  2022-02-04 09:07:05
# 2        4.00  2022-02-04 09:07:05
# 3        3.71  2022-02-04 09:03:02
# 4        5.19  2022-02-04 09:07:06

# %%
# Create the output file (CSV)
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
